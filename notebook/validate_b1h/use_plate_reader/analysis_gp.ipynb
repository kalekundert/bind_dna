# %%
import wellmap
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from kbkbio.plate_reader import BiotekExperiment
from scipy.optimize import curve_fit
from dataclasses import dataclass
from numpy import inf

def load_plate_reader(path):
    expt = BiotekExperiment(path)
    return expt.kinetic[600]

df = wellmap.load(
        '20220323_b1h_s4_s5_s16_s22.toml',
        data_loader=load_plate_reader,
        merge_cols=True,
        path_guess='{0.stem}.xlsx',
)
df = df.query('well == "D3"')
df
# Out:
#      well well0 row col  row_i  col_j  \
# 980    D3   D03   D   3      3      2
# 981    D3   D03   D   3      3      2
# 982    D3   D03   D   3      3      2
# 983    D3   D03   D   3      3      2
# 984    D3   D03   D   3      3      2
# 985    D3   D03   D   3      3      2
# 986    D3   D03   D   3      3      2
# 987    D3   D03   D   3      3      2
# 988    D3   D03   D   3      3      2
# 989    D3   D03   D   3      3      2
# 990    D3   D03   D   3      3      2
# 991    D3   D03   D   3      3      2
# 992    D3   D03   D   3      3      2
# 993    D3   D03   D   3      3      2
# 994    D3   D03   D   3      3      2
# 995    D3   D03   D   3      3      2
# 996    D3   D03   D   3      3      2
# 997    D3   D03   D   3      3      2
# 998    D3   D03   D   3      3      2
# 999    D3   D03   D   3      3      2
# 1000   D3   D03   D   3      3      2
# 1001   D3   D03   D   3      3      2
# 1002   D3   D03   D   3      3      2
# 1003   D3   D03   D   3      3      2
# 1004   D3   D03   D   3      3      2
# 1005   D3   D03   D   3      3      2
# 1006   D3   D03   D   3      3      2
# 1007   D3   D03   D   3      3      2
# 1008   D3   D03   D   3      3      2
# 1009   D3   D03   D   3      3      2
# 1010   D3   D03   D   3      3      2
# 1011   D3   D03   D   3      3      2
# 1012   D3   D03   D   3      3      2
# 1013   D3   D03   D   3      3      2
# 1014   D3   D03   D   3      3      2
# 1015   D3   D03   D   3      3      2
# 1016   D3   D03   D   3      3      2
# 1017   D3   D03   D   3      3      2
# 1018   D3   D03   D   3      3      2
# 1019   D3   D03   D   3      3      2
# 1020   D3   D03   D   3      3      2
# 1021   D3   D03   D   3      3      2
# 1022   D3   D03   D   3      3      2
# 1023   D3   D03   D   3      3      2
# 1024   D3   D03   D   3      3      2
# 1025   D3   D03   D   3      3      2
# 1026   D3   D03   D   3      3      2
# 1027   D3   D03   D   3      3      2
# 1028   D3   D03   D   3      3      2
#
#                                                    path  \
# 980   /home/kale/research/projects/201904_bind_dna/d...
# 981   /home/kale/research/projects/201904_bind_dna/d...
# 982   /home/kale/research/projects/201904_bind_dna/d...
# 983   /home/kale/research/projects/201904_bind_dna/d...
# 984   /home/kale/research/projects/201904_bind_dna/d...
# 985   /home/kale/research/projects/201904_bind_dna/d...
# 986   /home/kale/research/projects/201904_bind_dna/d...
# 987   /home/kale/research/projects/201904_bind_dna/d...
# 988   /home/kale/research/projects/201904_bind_dna/d...
# 989   /home/kale/research/projects/201904_bind_dna/d...
# 990   /home/kale/research/projects/201904_bind_dna/d...
# 991   /home/kale/research/projects/201904_bind_dna/d...
# 992   /home/kale/research/projects/201904_bind_dna/d...
# 993   /home/kale/research/projects/201904_bind_dna/d...
# 994   /home/kale/research/projects/201904_bind_dna/d...
# 995   /home/kale/research/projects/201904_bind_dna/d...
# 996   /home/kale/research/projects/201904_bind_dna/d...
# 997   /home/kale/research/projects/201904_bind_dna/d...
# 998   /home/kale/research/projects/201904_bind_dna/d...
# 999   /home/kale/research/projects/201904_bind_dna/d...
# 1000  /home/kale/research/projects/201904_bind_dna/d...
# 1001  /home/kale/research/projects/201904_bind_dna/d...
# 1002  /home/kale/research/projects/201904_bind_dna/d...
# 1003  /home/kale/research/projects/201904_bind_dna/d...
# 1004  /home/kale/research/projects/201904_bind_dna/d...
# 1005  /home/kale/research/projects/201904_bind_dna/d...
# 1006  /home/kale/research/projects/201904_bind_dna/d...
# 1007  /home/kale/research/projects/201904_bind_dna/d...
# 1008  /home/kale/research/projects/201904_bind_dna/d...
# 1009  /home/kale/research/projects/201904_bind_dna/d...
# 1010  /home/kale/research/projects/201904_bind_dna/d...
# 1011  /home/kale/research/projects/201904_bind_dna/d...
# 1012  /home/kale/research/projects/201904_bind_dna/d...
# 1013  /home/kale/research/projects/201904_bind_dna/d...
# 1014  /home/kale/research/projects/201904_bind_dna/d...
# 1015  /home/kale/research/projects/201904_bind_dna/d...
# 1016  /home/kale/research/projects/201904_bind_dna/d...
# 1017  /home/kale/research/projects/201904_bind_dna/d...
# 1018  /home/kale/research/projects/201904_bind_dna/d...
# 1019  /home/kale/research/projects/201904_bind_dna/d...
# 1020  /home/kale/research/projects/201904_bind_dna/d...
# 1021  /home/kale/research/projects/201904_bind_dna/d...
# 1022  /home/kale/research/projects/201904_bind_dna/d...
# 1023  /home/kale/research/projects/201904_bind_dna/d...
# 1024  /home/kale/research/projects/201904_bind_dna/d...
# 1025  /home/kale/research/projects/201904_bind_dna/d...
# 1026  /home/kale/research/projects/201904_bind_dna/d...
# 1027  /home/kale/research/projects/201904_bind_dna/d...
# 1028  /home/kale/research/projects/201904_bind_dna/d...
#
#                         media strain  dilution  temperature_C  time_min  \
# 980   NM + His+Ura + Carb+Kan     s4       3.0           37.0        29
# 981   NM + His+Ura + Carb+Kan     s4       3.0           37.0        59
# 982   NM + His+Ura + Carb+Kan     s4       3.0           37.0        89
# 983   NM + His+Ura + Carb+Kan     s4       3.0           37.0       119
# 984   NM + His+Ura + Carb+Kan     s4       3.0           37.1       149
# 985   NM + His+Ura + Carb+Kan     s4       3.0           37.0       179
# 986   NM + His+Ura + Carb+Kan     s4       3.0           37.1       209
# 987   NM + His+Ura + Carb+Kan     s4       3.0           37.0       239
# 988   NM + His+Ura + Carb+Kan     s4       3.0           37.0       269
# 989   NM + His+Ura + Carb+Kan     s4       3.0           37.0       299
# 990   NM + His+Ura + Carb+Kan     s4       3.0           37.0       329
# 991   NM + His+Ura + Carb+Kan     s4       3.0           37.0       359
# 992   NM + His+Ura + Carb+Kan     s4       3.0           37.0       389
# 993   NM + His+Ura + Carb+Kan     s4       3.0           37.0       419
# 994   NM + His+Ura + Carb+Kan     s4       3.0           37.0       449
# 995   NM + His+Ura + Carb+Kan     s4       3.0           37.0       479
# 996   NM + His+Ura + Carb+Kan     s4       3.0           37.0       509
# 997   NM + His+Ura + Carb+Kan     s4       3.0           37.0       539
# 998   NM + His+Ura + Carb+Kan     s4       3.0           37.0       569
# 999   NM + His+Ura + Carb+Kan     s4       3.0           37.0       599
# 1000  NM + His+Ura + Carb+Kan     s4       3.0           37.0       629
# 1001  NM + His+Ura + Carb+Kan     s4       3.0           37.0       659
# 1002  NM + His+Ura + Carb+Kan     s4       3.0           37.0       689
# 1003  NM + His+Ura + Carb+Kan     s4       3.0           37.0       719
# 1004  NM + His+Ura + Carb+Kan     s4       3.0           37.0       749
# 1005  NM + His+Ura + Carb+Kan     s4       3.0           37.0       779
# 1006  NM + His+Ura + Carb+Kan     s4       3.0           37.0       809
# 1007  NM + His+Ura + Carb+Kan     s4       3.0           37.0       839
# 1008  NM + His+Ura + Carb+Kan     s4       3.0           37.0       869
# 1009  NM + His+Ura + Carb+Kan     s4       3.0           37.0       899
# 1010  NM + His+Ura + Carb+Kan     s4       3.0           37.0       929
# 1011  NM + His+Ura + Carb+Kan     s4       3.0           37.0       959
# 1012  NM + His+Ura + Carb+Kan     s4       3.0           37.0       989
# 1013  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1019
# 1014  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1049
# 1015  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1079
# 1016  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1109
# 1017  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1139
# 1018  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1169
# 1019  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1199
# 1020  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1229
# 1021  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1259
# 1022  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1289
# 1023  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1319
# 1024  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1349
# 1025  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1379
# 1026  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1409
# 1027  NM + His+Ura + Carb+Kan     s4       3.0           37.0      1439
# 1028  NM + His+Ura + Carb+Kan     s4       3.0           37.1      1469
#
#       wavelength_nm   read
# 980             600  0.085
# 981             600  0.085
# 982             600  0.085
# 983             600  0.085
# 984             600  0.086
# 985             600  0.086
# 986             600  0.086
# 987             600  0.086
# 988             600  0.087
# 989             600  0.088
# 990             600  0.090
# 991             600  0.092
# 992             600  0.095
# 993             600  0.099
# 994             600  0.103
# 995             600  0.109
# 996             600  0.117
# 997             600  0.128
# 998             600  0.143
# 999             600  0.167
# 1000            600  0.187
# 1001            600  0.209
# 1002            600  0.230
# 1003            600  0.251
# 1004            600  0.270
# 1005            600  0.282
# 1006            600  0.297
# 1007            600  0.310
# 1008            600  0.325
# 1009            600  0.337
# 1010            600  0.347
# 1011            600  0.356
# 1012            600  0.365
# 1013            600  0.373
# 1014            600  0.381
# 1015            600  0.389
# 1016            600  0.397
# 1017            600  0.404
# 1018            600  0.410
# 1019            600  0.415
# 1020            600  0.421
# 1021            600  0.426
# 1022            600  0.430
# 1023            600  0.434
# 1024            600  0.439
# 1025            600  0.442
# 1026            600  0.446
# 1027            600  0.449
# 1028            600  0.452

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel

kernel = RBF(length_scale=1e2, length_scale_bounds=(1e1, 1e4)) + WhiteKernel()
gpr = GaussianProcessRegressor(
    kernel=kernel,
    normalize_y=True,
)

x = df['time_min'].values.reshape(-1, 1)
y = df['read'].values.reshape(-1, 1)

gpr.fit(x, y)

x_fit = np.linspace(0, 1600).reshape(-1, 1)
y_fit, y_std = gpr.predict(x_fit, return_std=True)
y_std = y_std.reshape(-1, 1)

plt.plot(x, y, '+')
plt.plot(x_fit, y_fit)
plt.plot(x_fit, y_fit+y_std, '--')
plt.plot(x_fit, y_fit-y_std, '--')

# %%
class BacterialGrowthRegressor:
    # Make my own class, because the derivative depends 
    # on the kernel, so all that has to be internal.
    pass

def gp_grad(gpr, x_star): 
    X = gpr.X_train_.ravel()
    K = gpr.kernel_
    l = K.k1.length_scale
    a = gpr.alpha_

    dx = X - x_star
    f = np.exp(-(dx**2) / (2*l**2))
    df = f * dx / l**2
    
    return df @ a

plt.plot(x_fit, [gp_grad(gpr, x) for x in x_fit])

# %%
from scipy.optimize import minimize_scalar

minimize_scalar(lambda x: -gp_grad(gpr, x), bounds=(0, 1500), method='bounded')
# Out:
#      fun: array([-0.0053281])
#  message: 'Solution found.'
#     nfev: 22
#      nit: 22
#   status: 0
#  success: True
#        x: array([638.09728695])
